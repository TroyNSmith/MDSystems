# %%
import matplotlib.pyplot as plt

from mdsystems import analysis, atoms

OH = atoms.System(traj="data/test.xtc", top="data/test.gro")

rdf, bins = analysis.Spatial.radial_distribution(OH, com=True)

plt.plot(bins, rdf)

# %%
from mdsystems import atoms

OH_OE = atoms.System(traj="data/test.xtc", top="data/test.gro", top_filter="name O2 or name O12")

OH_OE.times
# Out:
# array([[[4.25250053, 4.69250059, 2.29450011],
#         [1.46050012, 3.49550033, 5.16650009],
#         [0.101     , 5.56550026, 5.5720005 ],
#         ...,
#         [3.40100002, 1.62550008, 5.42650032],
#         [3.26550007, 3.11549997, 1.62450004],
#         [3.1275003 , 2.40300012, 5.18149996]],
#
#        [[4.21200037, 4.72050047, 2.32600021],
#         [1.37550008, 3.4690001 , 5.27400017],
#         [3.16250014, 5.54150009, 5.65150023],
#         ...,
#         [3.36550021, 1.59050012, 5.46000004],
#         [3.37550044, 6.0715003 , 1.69300008],
#         [3.08500028, 2.31150031, 5.18950033]],
#
#        [[4.18350029, 4.60050011, 2.32800007],
#         [1.36599994, 3.37850022, 5.27800035],
#         [3.13500023, 5.54650068, 5.68300056],
#         ...,
#         [3.42000031, 1.54550004, 5.34700012],
#         [3.36850023, 5.92500019, 1.74550009],
#         [3.19050002, 2.27400017, 5.23500013]],
#
#        ...,
#
#        [[5.71150064, 2.98350024, 0.93900007],
# ...
