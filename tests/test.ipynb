# %%
from mdsystems import atoms, temporal

# %%
OH = atoms.System("data/test.xtc", top="data/test.gro")

msd = temporal.MeanSquareDisplacement(OH)

times, results = msd.run(com=True)

# %%
import matplotlib.pyplot as plt

plt.plot(times, results)
plt.xscale("log")
